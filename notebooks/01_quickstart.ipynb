# %% [markdown]
# # ReactionForge Quick Start
# This notebook demonstrates basic usage of ReactionForge for reaction yield prediction.

# %%
import torch
from src.models.reactionforge import ReactionForge
from src.data.dataset import SuzukiMiyauraDataset

# %% [markdown]
# ## Load Model

# %%
# Initialize model
model = ReactionForge(node_feat_dim=154, edge_feat_dim=6, condition_dim=10)
model.eval()

# %% [markdown]
# ## Make Predictions
# See documentation for detailed examples.
